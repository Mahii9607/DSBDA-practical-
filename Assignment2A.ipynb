# %% [markdown]
# <a href="https://colab.research.google.com/github/Mahii9607/DSBDA-practical-/blob/main/Assignment2A.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df=pd.read_csv("/content/StudentPerformance.csv")

# %%
df1=df
df2=df1
df3=df
df4=df

# %%
df
# Out:
#     gender  math score                     reading score  writing score  \
# 0   female                           63.0           84.0             64
# 1   female                           71.0           80.0             76
# 2   female                           64.0           81.0             66
# 3     male                           71.0           85.0             77
# 4     male                           68.0           86.0             76
# 5   female                           94.0           86.0             61
# 6     male                           75.0           79.0             66
# 7   female                            NaN            NaN             66
# 8     male                           66.0           88.0             66
# 9     male                           70.0           79.0             61
# 10  female                          -99.0           80.0             65
# 11    male                           76.0           84.0            -99
# ...

# %%
df.isnull()
# Out:
#     gender  math score                     reading score  writing score  \
# 0    False                          False          False          False
# 1    False                          False          False          False
# 2    False                          False          False          False
# 3    False                          False          False          False
# 4    False                          False          False          False
# 5    False                          False          False          False
# 6    False                          False          False          False
# 7    False                           True           True          False
# 8    False                          False          False          False
# 9    False                          False          False          False
# 10   False                          False          False          False
# 11   False                          False          False          False
# ...

# %%
df.isnull().sum()
# Out:
# gender                           0
# math score                       1
# reading score                    1
# writing score                    0
# placement score                  2
# club join year                   0
# placement offer                  0
# dtype: int64

# %%
df.columns
# Out:
# Index(['gender', 'math score                   ', 'reading score',
#        'writing score', 'placement score', 'club join year',
#        'placement offer'],
#       dtype='object')

# %%
df.isnull().any()
# Out:
# gender                           False
# math score                        True
# reading score                     True
# writing score                    False
# placement score                   True
# club join year                   False
# placement offer                  False
# dtype: bool

# %%
pd.isnull(df["reading score"]).sum()
# Out:
# 1

# %%
df.notnull()
# Out:
#     gender  math score                     reading score  writing score  \
# 0     True                           True           True           True
# 1     True                           True           True           True
# 2     True                           True           True           True
# 3     True                           True           True           True
# 4     True                           True           True           True
# 5     True                           True           True           True
# 6     True                           True           True           True
# 7     True                          False          False           True
# 8     True                           True           True           True
# 9     True                           True           True           True
# 10    True                           True           True           True
# 11    True                           True           True           True
# ...

# %%
df.notnull().sum()
# Out:
# gender                           13
# math score                       12
# reading score                    12
# writing score                    13
# placement score                  11
# club join year                   13
# placement offer                  13
# dtype: int64

# %%
df.head()
df1=df

# %%
df.isnull().sum()
# Out:
# gender                           0
# math score                       1
# reading score                    1
# writing score                    0
# placement score                  2
# club join year                   0
# placement offer                  0
# dtype: int64

# %%
df[df['writing score'].isnull()].index.tolist()
# Out:
# []

# %%
df['writing score']=df['writing score'].fillna(df['writing score'].median())

# %%
df['writing score'].isnull().sum()
# Out:
# 0

# %%
df2.head()
# Out:
#    gender  math score                     reading score  writing score  \
# 0  female                           63.0           84.0             64
# 1  female                           71.0           80.0             76
# 2  female                           64.0           81.0             66
# 3    male                           71.0           85.0             77
# 4    male                           68.0           86.0             76
#
#    placement score  club join year  placement offer
# 0             84.0            2020                2
# 1             86.0            2018                3
# 2             81.0            2020                2
# 3             96.0            2018                1
# 4              NaN            2021                3

# %%
import numpy as np

# %%
df.isnull().sum()
# Out:
# gender                           0
# math score                       1
# reading score                    1
# writing score                    0
# placement score                  2
# club join year                   0
# placement offer                  0
# dtype: int64

# %%
df[df['reading score'].isnull()].index.tolist()
# Out:
# [7]

# %%
df.replace(to_replace = np.nan, value = 80)
# Out:
#     gender  math score                     reading score  writing score  \
# 0   female                           63.0           84.0             64
# 1   female                           71.0           80.0             76
# 2   female                           64.0           81.0             66
# 3     male                           71.0           85.0             77
# 4     male                           68.0           86.0             76
# 5   female                           94.0           86.0             61
# 6     male                           75.0           79.0             66
# 7   female                           80.0           80.0             66
# 8     male                           66.0           88.0             66
# 9     male                           70.0           79.0             61
# 10  female                          -99.0           80.0             65
# 11    male                           76.0           84.0            -99
# ...

# %%
df2.isnull().sum()
# Out:
# gender                           0
# math score                       1
# reading score                    1
# writing score                    0
# placement score                  2
# club join year                   0
# placement offer                  0
# dtype: int64

# %%
df3.isnull().sum()
# Out:
# gender                           0
# math score                       1
# reading score                    1
# writing score                    0
# placement score                  2
# club join year                   0
# placement offer                  0
# dtype: int64

# %%
df3[df3['reading score'].isnull()].index.tolist()
# Out:
# [7]

# %%
df3.dropna()
# Out:
#     gender  math score                     reading score  writing score  \
# 0   female                           63.0           84.0             64
# 1   female                           71.0           80.0             76
# 2   female                           64.0           81.0             66
# 3     male                           71.0           85.0             77
# 5   female                           94.0           86.0             61
# 6     male                           75.0           79.0             66
# 8     male                           66.0           88.0             66
# 9     male                           70.0           79.0             61
# 10  female                          -99.0           80.0             65
# 12  female                           74.0           79.0             79
#
#     placement score  club join year  placement offer
# 0              84.0            2020                2
# 1              86.0            2018                3
# ...

# %%
df4.dropna(axis = 1)
# Out:
#     gender  writing score  club join year  placement offer
# 0   female             64            2020                2
# 1   female             76            2018                3
# 2   female             66            2020                2
# 3     male             77            2018                1
# 4     male             76            2021                3
# 5   female             61            2019                1
# 6     male             66            2020                1
# 7   female             66            2019                3
# 8     male             66            2020                3
# 9     male             61            2021                2
# 10  female             65            2021                1
# 11    male            -99            2020                2
# 12  female             79            2019                2
